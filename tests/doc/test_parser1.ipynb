# %%
from biz.dfch.ste100parser import Parser
from biz.dfch.ste100parser import GrammarType
from biz.dfch.ste100parser import ContainerTransformer
# from biz.dfch.ste100parser import TextTransformer
from biz.dfch.ste100parser.transformer import TextTransformer
from biz.dfch.ste100parser import Token
from biz.dfch.ste100parser import Char

parser = Parser(GrammarType.CONTAINER)

# %%
value = '''When the system recognizes an applicable debit card, 
the system must show this message in less than 0.2 second:
"Type in the PIN."

'''

from lark import Tree

def test_are_equal(tree, start_token, tokens: list) -> None:
    assert tree is not None
    assert tree is not start_token
    assert isinstance(tokens, list)

    def get_tokens(children) -> list:
        result = [
            child[0] for child in children
            if isinstance(child, tuple)
        ]
        return result

    def get_token_tree(node: Tree | str) -> tuple[Token, list] | str:
        """
            Converts a Lark Tree into a nested structure using Token StrEnum
            values.
        """

        if not isinstance(node, Tree):
            return str(node)

        token = Token[node.data]

        children = [get_token_tree(c) for c in node.children]

        return (token, children)

    token_tree = get_tokens(tree)

    token, children = token_tree
    for _ in range(level):
        token, children = children[0]
    assert start_token == token

    result = get_tokens(children)
    assert expected == result

tree = parser.invoke(value)
pass1 = ContainerTransformer().transform(tree)
print(pass1.pretty())

pass2 = TextTransformer().transform(pass1)
print(pass2.pretty())

level = 0
parent = Token.start
expected = [
    Token.paragraph,
]

level = 1
parent = Token.paragraph
expected = [
    Token.sentence,
    Token.sentence,
]
# test_are_equal(pass2, parent, expected)

expected = [
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.COMMA,
    Token.WS,
    Token.LINEBREAK,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.WS,
    Token.WORD,
    Token.EOS,
]
level = 2
parent = Token.sentence
# Out:
# start
#   paragraph
#     TEXT	When
#     WS	1
#     TEXT	the
#     WS	1
#     TEXT	system
#     WS	1
#     TEXT	recognizes
#     WS	1
#     TEXT	an
#     WS	1
#     TEXT	applicable
#     WS	1
#     TEXT	debit
#     WS	1
#     TEXT	card,
#     WS	1
#     LINEBREAK
#
#     TEXT	the
#     WS	1
#     TEXT	system
#     WS	1
#     TEXT	must
#     WS	1
#     TEXT	show
#     WS	1
#     TEXT	this
#     WS	1
#     TEXT	message
#     WS	1
#     TEXT	in
#     WS	1
#     TEXT	less
#     WS	1
#     TEXT	than
#     WS	1
#     TEXT	0.2
#     WS	1
#     TEXT	second:
#     dquote
#       TEXT	Type
#       WS	1
#       TEXT	in
#       WS	1
#       TEXT	the
#       WS	1
#       TEXT	PIN.
#
# start
#   paragraph
#     sentence
#       WORD	When
#       WS	1
#       WORD	the
#       WS	1
#       WORD	system
#       WS	1
#       WORD	recognizes
#       WS	1
#       WORD	an
#       WS	1
#       WORD	applicable
#       WS	1
#       WORD	debit
#       WS	1
#       WORD	card
#       COMMA	,
#       WS	1
# ...
